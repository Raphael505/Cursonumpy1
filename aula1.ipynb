# %% [markdown]
# # O que vamos aprender

# %% [markdown]
# - O que e Numpy
# - Manipular arrays (ndarray)
# - Indexação
# - Operações vetorizadas
# - algebra Linear e Estatistica (Probalidade e Est Bayesiana)
# - Performance Numpy vs Lista Nativas python
# - Boas praticas e soluções do Projeto

# %%
print("Thomas Bayes vai reviver no tumulo!")

# %% [markdown]
# Por que o Numpy e o coração da ciencia de dados em Python?

# %% [markdown]
# - Pandas
# - Sciki-learn
# - TensorFlow (Redes neurais)
# - Matplotlib

# %%
import numpy as np

# %% [markdown]
# - Lista do Python x Array do Numpy

# %% [markdown]
# ### Por que o Numpy Array e mais rapido que uma lista Python ###

# %% [markdown]
# - Lista e a sacola do supermercado
# - Array do Numpy - caixa de ovos
# - C e fortran: 50x
# - O Numpy Permite a Vetorização

# %% [markdown]
# # Aula 1 - Download de DataSets
